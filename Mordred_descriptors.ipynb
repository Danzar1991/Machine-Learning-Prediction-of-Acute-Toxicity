# %% [markdown]
# # Download data

# %%
! gdown --id 18WwPBK-TOpeYAUpUG3Ov4lfbo0nnhK1o
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=18WwPBK-TOpeYAUpUG3Ov4lfbo0nnhK1o
# To: /content/Acute Toxicity_mouse_intraperitoneal_LD50.csv
# 100% 6.86M/6.86M [00:00<00:00, 40.3MB/s]

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Acute Toxicity_mouse_intraperitoneal_LD50.csv")

# %% [markdown]
# # Download rdkit and mordred libraries

# %%
# !pip install rdkit
# !pip install mordred
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (36.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 56.2 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.9.1
# Collecting mordred
#   Downloading mordred-1.2.0.tar.gz (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six==1.* in /usr/local/lib/python3.12/dist-packages (from mordred) (1.17.0)
# Collecting numpy==1.* (from mordred)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.2 MB/s eta 0:00:00
# Collecting networkx==2.* (from mordred)
#   Downloading networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 47.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 64.3 MB/s eta 0:00:00
# Building wheels for collected packages: mordred
#   Building wheel for mordred (setup.py) ... done
#   Created wheel for mordred: filename=mordred-1.2.0-py3-none-any.whl size=176718 sha256=3d4019f96196bb74438c0aaacf07f4c5bc42e4e0b42cd133cb2135a675b8a5ae
#   Stored in directory: /root/.cache/pip/wheels/e8/79/b8/f4f1dfbb736c2b8605cf5068cd633f4d2869defb89908aef93
# Successfully built mordred
# Installing collected packages: numpy, networkx, mordred
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.25.2 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# nx-cugraph-cu12 25.6.0 requires networkx>=3.2, but you have networkx 2.8.8 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed mordred-1.2.0 networkx-2.8.8 numpy-1.26.4

# %% [markdown]
# # Import libraries

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from mordred import Calculator, descriptors
import mordred

# %% [markdown]
# # Data verification

# %%
data.head()
# Out:
#        TAID  Pubchem CID                                         IUPAC Name  \
# 0   TOX-145          785                                   benzene-1,4-diol
# 1   TOX-245         5453  tris(aziridin-1-yl)-sulfanylidene-lambda5-phos...
# 2  TOX-1273          727                  1,2,3,4,5,6-hexachlorocyclohexane
# 3  TOX-1279         4091       3-(diaminomethylidene)-1,1-dimethylguanidine
# 4  TOX-1282        10364                       2-methyl-5-propan-2-ylphenol
#
#                          SMILES              Canonical SMILES  \
# 0                  Oc1ccc(O)cc1                  Oc1ccc(O)cc1
# 1        S=P(N1CC1)(N1CC1)N1CC1        S=P(N1CC1)(N1CC1)N1CC1
# 2  ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl  ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl
# 3             CN(C)C(=N)N=C(N)N             CN(C)C(=N)N=C(N)N
# 4             Cc1ccc(C(C)C)cc1O             Cc1ccc(C(C)C)cc1O
#
#                       InChIKey  mouse_intraperitoneal_LD50
# 0  QIGBRXMKCJKVMJ-UHFFFAOYSA-N                    3.041835
# 1  FOCVUCIESVLUNU-UHFFFAOYSA-N                    4.235584
# 2  JLYXXMFPNIAWKQ-UHFFFAOYSA-N                    3.366732
# 3  XZWYZXLIPXDOLR-UHFFFAOYSA-N                    2.641604
# 4  RECUKUPTGUEGMW-UHFFFAOYSA-N                    3.311627

# %%
data.isna().sum()
# Out:
# TAID                             0
# Pubchem CID                      0
# IUPAC Name                    1919
# SMILES                           0
# Canonical SMILES                 0
# InChIKey                        38
# mouse_intraperitoneal_LD50       0
# dtype: int64

# %%
data.shape
# Out:
# (35299, 7)

# %%
data['SMILES'].nunique()
# Out:
# 35299

# %%
data['Canonical SMILES'].nunique()
# Out:
# 35299

# %% [markdown]
# # Converting molecules from SMILES strings to RDKit objects

# %%
mol_dataset = data['SMILES'].apply(lambda x: Chem.MolFromSmiles(x))
mol = pd.DataFrame(mol_dataset)

# %% [markdown]
# # Сalculation of descriptors

# %%
calc = Calculator(descriptors, ignore_3D=True)
data = calc.pandas(mol_dataset)
# Out:
#   2%|▏         | 694/35299 [02:36<2:16:10,  4.24it/s]
# /usr/local/lib/python3.12/dist-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   2%|▏         | 732/35299 [02:47<3:29:34,  2.75it/s]
# /usr/local/lib/python3.12/dist-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 35299/35299 [1:38:22<00:00,  5.98it/s]

# %%
data= data.select_dtypes(exclude=[mordred.error.Missing])
data.head()
# Out:
#    nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A     SpAD_A   SpMAD_A   LogEE_A  \
# 0      0      0   9.924777  2.170086  4.340173   9.924777  1.240597  2.979730
# 1      0      0  15.203358  2.601679  4.863481  15.203358  1.382123  3.544956
# 2      0      0  14.601126  2.414214  4.828427  14.601126  1.216761  3.391683
# 3      0      5   9.335326  2.116883  4.233766   9.335326  1.037258  3.028326
# 4      0      0  13.152542  2.292456  4.584911  13.152542  1.195686  3.294652
#
#       VE1_A     VE2_A  ...     SRW09     SRW10     TSRW10          MW  \
# 0  2.742040  0.342755  ...  0.000000  8.463159  35.730685  110.036779
# 1  3.159945  0.287268  ...  8.503703  9.891769  66.234321  189.048955
# 2  3.200413  0.266701  ...  0.000000  9.542876  43.309911  287.860066
# 3  2.774515  0.308279  ...  0.000000  8.267962  36.359125  129.101445
# 4  3.103869  0.282170  ...  0.000000  9.071423  40.991311  150.104465
#
#          AMW  WPath  WPol  Zagreb1  Zagreb2  mZagreb2
# 0   7.859770     62     7     36.0     38.0  1.833333
# 1   8.219520    139    18     68.0     88.0  2.250000
# 2  15.992226    174    21     60.0     72.0  2.666667
# 3   6.455072     96     8     36.0     36.0  2.111111
# 4   6.004179    152    14     52.0     58.0  2.472222
#
# [5 rows x 934 columns]

# %%
data.to_csv('/content/mordred_descriptors.csv')
